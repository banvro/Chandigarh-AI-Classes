# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
x, y = make_regression(
    n_samples = 150,
    n_features = 2,
    n_informative = 2,
    n_targets = 1
)

# %%
x
# Out:
# array([[ 0.40115335,  0.75439625],
#        [-1.52801639,  0.10098737],
#        [-0.17007355, -0.13375732],
#        [-0.40062569,  1.16876855],
#        [-0.05945043,  1.35679762],
#        [-1.36424498, -0.8051246 ],
#        [-0.26977078,  0.39020945],
#        [ 0.80942085, -0.62217336],
#        [ 1.57912838,  0.3153279 ],
#        [ 0.66187473,  0.55512708],
#        [-1.6211661 , -0.75922423],
#        [ 2.53761155,  2.30112601],
#        [-0.43155995,  1.13707251],
#        [ 0.605947  , -0.59454077],
#        [ 0.88224435,  1.50441606],
#        [-0.0523543 ,  0.39477579],
#        [-0.88927423, -0.68466639],
#        [ 0.51750192,  0.56907674],
#        [ 0.15526873, -1.87752336],
#        [ 1.17674376,  0.87103243],
#        [ 0.86630857,  0.75534389],
#        [-0.22122556, -2.49751892],
#        [-0.09045   , -2.75663702],
#        [-1.54510195,  0.3077262 ],
#        [ 0.63209167, -1.11144411],
#        [ 0.31242687,  0.8067303 ],
#        [ 0.32271972, -0.45975125],
# ...

# %%
x.shape
# Out:
# (150, 2)

# %%
y
# Out:
# array([ 23.29914065, -75.89771565,  -9.07407506, -14.96463823,
#          2.89149456, -71.63074537, -11.79102006,  37.74782695,
#         80.24957674,  35.46295578, -84.26727242, 136.71053283,
#        -16.64692635,  27.70240833,  50.57276106,  -0.90997904,
#        -47.382599  ,  28.31089311,  -0.35432498,  62.54861009,
#         46.54064989, -21.84097541, -16.42731698, -75.85812713,
#         26.7754567 ,  19.09278284,  14.13572793, -94.99604684,
#         35.87283899, -29.04382911, -27.64672963,  12.66030768,
#        -44.97199309, -49.99388037,  18.34979083,  -1.65347126,
#          1.05050961,  37.62500671,  20.24313546, -46.36805569,
#        -57.12399627,  10.73659946, -35.59725649, -13.49281274,
#        -41.15436806,  52.40496871,  -0.46363626, -23.80359732,
#         13.92369575, -37.98292867,  58.97176293,  29.75823714,
#         17.76048467, -25.02104528,  74.22219088, -41.63070899,
#        -16.19441545, 114.19770945, -68.36777237,  51.98472954,
# ...

# %%
y.shape
# Out:
# (150,)

# %%
df = pd.DataFrame({
    "feature1" : x[: , 0],
    "feature2" : x[: , 1],
    "target" : y
})

# %%
df
# Out:
#      feature1  feature2     target
# 0    0.401153  0.754396  23.299141
# 1   -1.528016  0.100987 -75.897716
# 2   -0.170074 -0.133757  -9.074075
# 3   -0.400626  1.168769 -14.964638
# 4   -0.059450  1.356798   2.891495
# ..        ...       ...        ...
# 145  0.146663  0.447474   9.259835
# 146  0.787066 -0.826474  35.748450
# 147  1.276794  0.085062  64.151342
# 148  0.317072  1.221930  21.118516
# 149  0.883912  0.425962  45.997133
#
# [150 rows x 3 columns]

# %%
df.shape
# Out:
# (150, 3)

# %%
import plotly.express as px

# %%
px.scatter_3d(
    df, 
    x = df["feature1"],
    y = df["feature2"],
    z = df["target"]
)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x.shape
# Out:
# (150, 2)

# %%
x_train.shape
# Out:
# (120, 2)

# %%
x_test.shape
# Out:
# (30, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
mymodel = LinearRegression()

# %%
mymodel.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
mymodel.coef_
# Out:
# array([49.95626046,  4.32003679])

# %%
mymodel.intercept_
# Out:
# -4.440892098500626e-16

# %%
# # y = b0 + b1x1 + b2x2

# y = -4.440892098500626e-16 + 49.95626046*

# %%
x_test
# Out:
# array([[-0.84412545,  0.1246846 ],
#        [-0.80674838,  0.72531376],
#        [ 1.21764643, -3.03714413],
#        [-0.94275449,  0.06082606],
#        [-0.47365553, -0.03276319],
#        [ 0.86630857,  0.75534389],
#        [-1.10306574, -0.46734714],
#        [-0.54043006, -0.70596446],
#        [-0.22122556, -2.49751892],
#        [ 0.46727561, -0.4994591 ],
#        [-0.22087815, -0.56910772],
#        [ 0.90051666,  0.75417497],
#        [ 1.14392912,  0.5960227 ],
#        [ 0.63209167, -1.11144411],
#        [-1.03618991,  0.64563864],
#        [-0.0523543 ,  0.39477579],
#        [ 0.31242687,  0.8067303 ],
#        [ 1.24311579, -0.24666126],
#        [-0.26977078,  0.39020945],
#        [ 1.32294248,  0.31090698],
#        [-1.6211661 , -0.75922423],
#        [ 0.26696016,  0.20613408],
#        [ 0.15526873, -1.87752336],
#        [ 1.32926759, -1.72069715],
#        [ 0.16024816,  0.32672289],
#        [ 0.67311145,  1.0685554 ],
#        [ 0.4111801 , -0.06895417],
# ...

# %%
# y = b0 + b1x1 + b2x2

y = -4.440892098500626e-16 + 49.95626046*(-0.84412545) + 4.32003679*0.1246846

# %%
y_test
# Out:
# array([-41.63070899, -37.16874983,  47.70848762, -46.83371824,
#        -23.80359732,  46.54064989, -57.12399627, -30.04765719,
#        -21.84097541,  21.18566043, -13.49281274,  48.2445084 ,
#         59.72126122,  26.7754567 , -48.97499025,  -0.90997904,
#         19.09278284,  61.03583054, -11.79102006,  67.43238851,
#        -84.26727242,  14.22683806,  -0.35432498,  58.97176293,
#          9.41685386,  38.24232945,  20.24313546,  45.99713305,
#        -34.95707038,  36.60567584])

# %%
y
# Out:
# -41.63070878196828

# %%
mymodel.predict([[0.61958866,  1.30863315]])
# Out:
# array([36.60567583])

# %%
import plotly.graph_objects as go
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

z_final = mymodel.predict(final).reshape(10,10)

z = z_final
final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
     

fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()

# %%
y_pred = mymodel.predict(x_test)

# %%
x_test
# Out:
# array([[-0.84412545,  0.1246846 ],
#        [-0.80674838,  0.72531376],
#        [ 1.21764643, -3.03714413],
#        [-0.94275449,  0.06082606],
#        [-0.47365553, -0.03276319],
#        [ 0.86630857,  0.75534389],
#        [-1.10306574, -0.46734714],
#        [-0.54043006, -0.70596446],
#        [-0.22122556, -2.49751892],
#        [ 0.46727561, -0.4994591 ],
#        [-0.22087815, -0.56910772],
#        [ 0.90051666,  0.75417497],
#        [ 1.14392912,  0.5960227 ],
#        [ 0.63209167, -1.11144411],
#        [-1.03618991,  0.64563864],
#        [-0.0523543 ,  0.39477579],
#        [ 0.31242687,  0.8067303 ],
#        [ 1.24311579, -0.24666126],
#        [-0.26977078,  0.39020945],
#        [ 1.32294248,  0.31090698],
#        [-1.6211661 , -0.75922423],
#        [ 0.26696016,  0.20613408],
#        [ 0.15526873, -1.87752336],
#        [ 1.32926759, -1.72069715],
#        [ 0.16024816,  0.32672289],
#        [ 0.67311145,  1.0685554 ],
#        [ 0.4111801 , -0.06895417],
# ...

# %%
y_test
# Out:
# array([-41.63070899, -37.16874983,  47.70848762, -46.83371824,
#        -23.80359732,  46.54064989, -57.12399627, -30.04765719,
#        -21.84097541,  21.18566043, -13.49281274,  48.2445084 ,
#         59.72126122,  26.7754567 , -48.97499025,  -0.90997904,
#         19.09278284,  61.03583054, -11.79102006,  67.43238851,
#        -84.26727242,  14.22683806,  -0.35432498,  58.97176293,
#          9.41685386,  38.24232945,  20.24313546,  45.99713305,
#        -34.95707038,  36.60567584])

# %%
y_pred
# Out:
# array([-41.63070899, -37.16874983,  47.70848762, -46.83371824,
#        -23.80359732,  46.54064989, -57.12399627, -30.04765719,
#        -21.84097541,  21.18566043, -13.49281274,  48.2445084 ,
#         59.72126122,  26.7754567 , -48.97499025,  -0.90997904,
#         19.09278284,  61.03583054, -11.79102006,  67.43238851,
#        -84.26727242,  14.22683806,  -0.35432498,  58.97176293,
#          9.41685386,  38.24232945,  20.24313546,  45.99713305,
#        -34.95707038,  36.60567584])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred, y_test)
# Out:
# 1.0

# %%
import joblib

# %%
joblib.dump(mymodel, "predcitor.joblib")
# Out:
# ['predcitor.joblib']
