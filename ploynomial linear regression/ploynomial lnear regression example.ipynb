# %%
import numpy as np

# %%
x = 6 * np.random.rand(200, 1) - 3
y = 0.8 * x ** 2 + 0.9 * x + 2 + np.random.randn(200, 1)

# %%
x
# Out:
# array([[-4.12641782e-01],
#        [ 1.81839586e+00],
#        [ 1.47274265e+00],
#        [ 2.70024052e+00],
#        [ 2.96249640e+00],
#        [-1.25229125e-01],
#        [-2.05131262e+00],
#        [-2.19896641e+00],
#        [-2.07821057e-02],
#        [ 2.43045578e+00],
#        [-9.34180406e-02],
#        [-2.67803697e-01],
#        [ 2.23846742e+00],
#        [-2.74641182e+00],
#        [-1.19339421e-01],
#        [ 2.65830737e+00],
#        [-1.23102083e+00],
#        [ 2.04156388e+00],
#        [-2.70158226e+00],
#        [-7.29905180e-01],
#        [ 2.26295269e-01],
#        [-2.14634846e+00],
#        [ 1.28353246e+00],
#        [ 1.98773068e+00],
#        [ 2.98873698e+00],
#        [ 1.27950979e+00],
#        [-2.51795994e+00],
#        [-1.50661426e+00],
#        [-1.04179956e+00],
#        [-2.14756415e+00],
#        [ 2.89214374e+00],
#        [-8.15558179e-03],
#        [-1.37289488e+00],
#        [-2.07987949e+00],
#        [-5.57306612e-01],
# ...

# %%
y
# Out:
# array([[ 2.66970185],
#        [ 7.8826342 ],
#        [ 5.48186987],
#        [11.09430133],
#        [10.75349241],
#        [ 1.64962754],
#        [ 3.16386203],
#        [ 2.3315732 ],
#        [ 1.88525067],
#        [10.04909247],
#        [ 2.5779488 ],
#        [ 3.17659796],
#        [ 7.21245334],
#        [ 3.98740556],
#        [ 0.65668677],
#        [10.85976251],
#        [ 3.00456987],
#        [ 9.30347905],
#        [ 7.18589959],
#        [ 1.60751331],
#        [ 3.7945861 ],
#        [ 4.4409828 ],
#        [ 4.14101867],
#        [ 4.97969559],
#        [11.39000495],
#        [ 5.13348065],
#        [ 4.87318879],
#        [ 4.40553362],
#        [ 3.0935958 ],
#        [ 3.97674662],
#        [11.35945318],
#        [-0.55708069],
#        [ 0.47306469],
#        [ 1.14581008],
#        [ 2.01394214],
#        [ 0.95448094],
#        [ 5.64907857],
#        [ 3.31463512],
#        [10.67436104],
#        [ 3.93630625],
#        [ 2.24128384],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
plt.scatter(x_train, y_train, color = "green", label = "traning data")
plt.scatter(x_test, y_test, color = "red", label = "testing data")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend()

# %% [markdown]
# # Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train, y_train, color = "green", label = "traning data")
plt.scatter(x_test, y_test, color = "red", label = "testing data")
plt.plot(x_test, model.predict(x_test), color = "blue", label = "Predicted line")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, model.predict(x_test))
# Out:
# 0.3456657750310347

# %% [markdown]
# # Ploynomial Linear regression

# %%
x
# Out:
# array([[-4.12641782e-01],
#        [ 1.81839586e+00],
#        [ 1.47274265e+00],
#        [ 2.70024052e+00],
#        [ 2.96249640e+00],
#        [-1.25229125e-01],
#        [-2.05131262e+00],
#        [-2.19896641e+00],
#        [-2.07821057e-02],
#        [ 2.43045578e+00],
#        [-9.34180406e-02],
#        [-2.67803697e-01],
#        [ 2.23846742e+00],
#        [-2.74641182e+00],
#        [-1.19339421e-01],
#        [ 2.65830737e+00],
#        [-1.23102083e+00],
#        [ 2.04156388e+00],
#        [-2.70158226e+00],
#        [-7.29905180e-01],
#        [ 2.26295269e-01],
#        [-2.14634846e+00],
#        [ 1.28353246e+00],
#        [ 1.98773068e+00],
#        [ 2.98873698e+00],
#        [ 1.27950979e+00],
#        [-2.51795994e+00],
#        [-1.50661426e+00],
#        [-1.04179956e+00],
#        [-2.14756415e+00],
#        [ 2.89214374e+00],
#        [-8.15558179e-03],
#        [-1.37289488e+00],
#        [-2.07987949e+00],
#        [-5.57306612e-01],
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
ploy = PolynomialFeatures(degree = 2)

# %%
x_train
# Out:
# array([[ 1.81839586e+00],
#        [ 1.85217074e+00],
#        [-1.89037279e-01],
#        [-1.25229125e-01],
#        [ 2.26295269e-01],
#        [ 2.87271395e+00],
#        [ 2.08556865e+00],
#        [-2.14634846e+00],
#        [ 1.75178640e+00],
#        [ 2.54485144e+00],
#        [ 1.98773068e+00],
#        [ 2.98873698e+00],
#        [-2.93053768e+00],
#        [ 2.41234783e+00],
#        [-1.32935259e+00],
#        [-2.23240357e+00],
#        [ 2.44278603e-02],
#        [-2.42974435e+00],
#        [ 2.93418757e+00],
#        [-6.70410013e-01],
#        [-1.37289488e+00],
#        [-4.47964042e-01],
#        [ 1.28353246e+00],
#        [ 1.30578289e+00],
#        [ 2.11891852e+00],
#        [-2.07987949e+00],
#        [ 9.14721963e-01],
#        [-2.07218316e-01],
#        [ 8.34794819e-01],
#        [-2.19896641e+00],
#        [-5.57306612e-01],
#        [ 2.23846742e+00],
#        [ 1.21868775e-01],
#        [ 1.79069903e+00],
#        [ 4.20472269e-01],
# ...

# %%
x_train_new = ploy.fit_transform(x_train)

# %%
x_train_new
# Out:
# array([[ 1.00000000e+00,  1.81839586e+00,  3.30656350e+00],
#        [ 1.00000000e+00,  1.85217074e+00,  3.43053644e+00],
#        [ 1.00000000e+00, -1.89037279e-01,  3.57350929e-02],
#        [ 1.00000000e+00, -1.25229125e-01,  1.56823339e-02],
#        [ 1.00000000e+00,  2.26295269e-01,  5.12095488e-02],
#        [ 1.00000000e+00,  2.87271395e+00,  8.25248545e+00],
#        [ 1.00000000e+00,  2.08556865e+00,  4.34959658e+00],
#        [ 1.00000000e+00, -2.14634846e+00,  4.60681173e+00],
#        [ 1.00000000e+00,  1.75178640e+00,  3.06875559e+00],
#        [ 1.00000000e+00,  2.54485144e+00,  6.47626885e+00],
#        [ 1.00000000e+00,  1.98773068e+00,  3.95107325e+00],
#        [ 1.00000000e+00,  2.98873698e+00,  8.93254876e+00],
#        [ 1.00000000e+00, -2.93053768e+00,  8.58805107e+00],
#        [ 1.00000000e+00,  2.41234783e+00,  5.81942207e+00],
#        [ 1.00000000e+00, -1.32935259e+00,  1.76717831e+00],
#        [ 1.00000000e+00, -2.23240357e+00,  4.98362568e+00],
# ...

# %%
x_test_new = ploy.fit_transform(x_test)

# %%
x_test_new
# Out:
# array([[ 1.00000000e+00, -1.65274903e+00,  2.73157934e+00],
#        [ 1.00000000e+00,  2.64517136e+00,  6.99693153e+00],
#        [ 1.00000000e+00,  2.15865298e+00,  4.65978267e+00],
#        [ 1.00000000e+00,  1.62543718e+00,  2.64204602e+00],
#        [ 1.00000000e+00, -1.40449073e+00,  1.97259420e+00],
#        [ 1.00000000e+00, -2.85592320e+00,  8.15629733e+00],
#        [ 1.00000000e+00,  2.54050210e-01,  6.45415091e-02],
#        [ 1.00000000e+00,  2.94854218e+00,  8.69390100e+00],
#        [ 1.00000000e+00, -2.81429140e+00,  7.92023611e+00],
#        [ 1.00000000e+00,  1.25593724e+00,  1.57737836e+00],
#        [ 1.00000000e+00,  2.73177338e+00,  7.46258580e+00],
#        [ 1.00000000e+00, -1.72726914e-01,  2.98345869e-02],
#        [ 1.00000000e+00, -2.14756415e+00,  4.61203179e+00],
#        [ 1.00000000e+00, -2.99820149e+00,  8.98921220e+00],
#        [ 1.00000000e+00, -2.51304816e+00,  6.31541105e+00],
#        [ 1.00000000e+00, -7.32639224e-01,  5.36760232e-01],
# ...

# %%
ploy_model = LinearRegression()

# %%
ploy_model.fit(x_train_new, y_train)
# Out:
# LinearRegression()

# %%
ploy_model.coef_
# Out:
# array([[0.        , 0.78343052, 0.8371752 ]])

# %%
ploy_model.intercept_
# Out:
# array([1.96378448])

# %%
# 5

# %%
ploy.fit_transform([[5]])
# Out:
# array([[ 1.,  5., 25.]])

# %%
import joblib

# %%
joblib.dump(ploy_model, "predcterrr.joblib")
# Out:
# ['predcterrr.joblib']

# %%
r2_score(y_test, ploy_model.predict(x_test_new))
# Out:
# 0.9046049291005416
